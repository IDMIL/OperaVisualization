# %%
import xml.etree.ElementTree as ET

# %%
with open('scanscore_xml/Act 2.xml', 'r', encoding='utf8') as f:
    tree = ET.parse(f)

# %%
root = tree.getroot()

# %%
h = tree.find(".//page-height")

# %%
print(h.text)
# Out:
# 2970

# %%
tree.find(".//defaults").find(".//left-margin").text
# Out:
# '150'

# %%
tree.find(".//defaults").text
# Out:
# '\n        '

# %%
parts = tree.findall(".//part")

# %%
parts[0].findall("measure")[1].find("print")
